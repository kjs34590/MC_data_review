# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt 

# seaboarn lib add
import seaborn as sns

import time

# %matplotlib inline


import json 

import warnings
warnings.filterwarnings(action='ignore')

from datetime import date, datetime, timedelta
from dateutil.parser import parse


print('numpy version  - ' , np.__version__)
print('pandas version - ' , pd.__version__)

# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
    print('d')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
    print('w')
else:
    print('Unknown system... sorry~~~~') 


# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# numpy version  -  1.20.1
# pandas version -  1.2.4
# w

# %% [markdown]
# - conda install -c conda-forge selenium

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen , urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

import requests
import re

from selenium import webdriver

# %%
path   = './driver/chromedriver.exe'
driver = webdriver.Chrome(path) 
driver.get('https://python.org')

# %% [markdown]
# #### Selenium 함수
# - find_element_by_XXXX()
# - find_elements_by_XXXX()
#
# - _css_selector , _tag_name , _name , _id , _class_name

# %%
menu = driver.find_elements_by_css_selector('#top .meta-navigation ul.menu li')[3]
menu
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="be6dbed8cc40e9e873cbb9621b9d34ac", element="4ac8b12e-77bf-48e9-8876-f5662a129376")>

# %%
menu.click()

# %% [markdown]
# - https://datalab.naver.com/shoppingInsight/sCategory.naver

# %%
driver = webdriver.Chrome(path) 
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

# %%
ul_tag = driver.find_element_by_css_selector('ul.rank_top1000_list')
ul_tag
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b8fceab48cc4defaf4332db421b94c81", element="cfc9a199-dfd8-4e42-a0bc-3d0a71034b40")>

# %%
li_tags = ul_tag.find_elements_by_tag_name('li')

# %%
for li in li_tags :
    print(li.text.split('\n'))
# Out:
# ['1', '원피스']
# ['2', '가을원피스']
# ['3', '나이키후드티']
# ['4', '나이키바람막이']
# ['5', '써스데이아일랜드원피스']
# ['6', '반팔티']
# ['7', '반바지']
# ['8', '트위드자켓']
# ['9', '트렌치코트']
# ['10', '후드집업']
# ['11', '바람막이']
# ['12', '블라우스']
# ['13', '맨투맨']
# ['14', '폴로가디건']
# ['15', '팬츠']
# ['16', '가디건']
# ['17', '후드티']
# ['18', '잠옷']
# ['19', '남자팬티']
# ['20', '롱원피스']

# %%
next_tag = driver.find_element_by_css_selector('a.btn_page_next')
next_tag
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c3c9cd4e7e6e69d3dea5e3b40e5f0c3e", element="cbd528a9-5eff-4ef6-acac-98f9dfb9d5dd")>

# %%
if next_tag.is_enabled() :
    next_tag.click()

# %% [markdown]
# - 1 ~ 25 page 내용 추출하기 [실습]

# %%
driver = webdriver.Chrome(path) 
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

next_tag = driver.find_element_by_css_selector('a.btn_page_next')

shop_list = []
for idx in range(1, 26) :
    print('page - ' , idx)
    ul_tag = driver.find_element_by_css_selector('ul.rank_top1000_list')
    li_tags = ul_tag.find_elements_by_tag_name('li')
    
    for li in li_tags :
        shop_list.append( li.text.split('\n') ) 
        
    time.sleep(5)
    next_tag.click()
# Out:
# page -  1
# page -  2
# page -  3
# page -  4
# page -  5
# page -  6
# page -  7
# page -  8
# page -  9
# page -  10
# page -  11
# page -  12
# page -  13
# page -  14
# page -  15
# page -  16
# page -  17
# page -  18
# page -  19
# page -  20
# page -  21
# page -  22
# page -  23
# page -  24
# page -  25

# %%
shop_list
# Out:
# [['1', '원피스'],
#  ['22', '케네스레이디원피스'],
#  ['23', '메종키츠네맨투맨'],
#  ['24', '라코스테가디건'],
#  ['25', '여성가디건'],
#  ['26', '폴로니트'],
#  ['27', '쥬시쥬디'],
#  ['28', '메종키츠네가디건'],
#  ['29', '폴로셔츠'],
#  ['30', '버버리퀼팅자켓'],
#  ['31', '여성트레이닝세트'],
#  ['32', '아노락'],
#  ['33', '데님원피스'],
#  ['34', '니트조끼'],
#  ['35', '메종키츠네'],
#  ['36', '강블리gbl남여공용무지반팔7색'],
#  ['37', '스톤아일랜드맨투맨'],
#  ['38', '스포츠브라'],
#  ['39', '모조에스핀원피스'],
#  ['40', '폴로랄프로렌'],
#  ['21', '나이키후드집업'],
#  ['42', '뷔스티에원피스'],
#  ['43', '지고트원피스'],
#  ['44', '남자가디건'],
#  ['45', '커플잠옷'],
#  ['46', '하객원피스'],
#  ['47', '니트원피스'],
#  ['48', '온앤온원피스'],
#  ['49', '트위드원피스'],
#  ['50', '나이키맨투맨'],
#  ['51', '써스데이아일랜드'],
#  ['52', '잇미샤원피스'],
#  ['53', '모조에스핀'],
#  ['54', '꼼데가르송가디건'],
#  ['55', '스톤아일랜드'],
#  ['56', '미즈바이베이지'],
#  ['57', '조거팬츠'],
#  ['58', '여성블라우스'],
#  ['59', '아디다스바람막이'],
#  ['60', '세인트제임스'],
#  ['61', '로엠원피스'],
#  ['62', '에고이스트'],
#  ['63', '브라렛'],
#  ['64', '나이키아노락'],
#  ['65', '톰브라운가디건'],
#  ['66', '니트베스트'],
#  ['67', '잇미샤'],
#  ['68', '시슬리원피스'],
#  ['69', '아미맨투맨'],
#  ['70', '톰브라운'],
#  ['71', '라코스테원피스'],
#  ['72', '보웬'],
#  ['73', '우비'],
#  ['74', '플라스틱아일랜드원피스'],
#  ['75', '청바지'],
#  ['76', '여성팬티'],
#  ['77', '여성니트조끼'],
#  ['78', '스튜디오톰보이'],
#  ['79', '달콤한레드스윗드림신혼부부파자마수면커플잠옷'],
#  ['80', '타미힐피거'],
#  ['81', '생활한복'],
#  ['82', '듀엘'],
#  ['83', '지컷원피스'],
#  ['84', '필잇'],
#  ['85', '셀프웨딩드레스'],
#  ['86', '하이서포트브라탑스포츠브라'],
#  ['87', '캘빈클라인언더웨어'],
#  ['88', '아미가디건'],
#  ['89', '로엠'],
#  ['90', '비비안웨스트우드가디건'],
#  ['91', '롱스커트'],
#  ['92', '에잇세컨즈'],
#  ['93', '에고이스트원피스'],
#  ['94', '스커트'],
#  ['95', '레노마'],
#  ['96', '여자조거팬츠'],
#  ['97', '트위드베스트'],
#  ['98', '쉬즈미스원피스'],
#  ['99', '여성원피스'],
#  ['100', '여성점프수트'],
#  ['101', '남자바람막이'],
#  ['102', '여자속옷'],
#  ['103', '듀엘원피스'],
#  ['104', '지컷'],
#  ['105', '남자셔츠'],
#  ['106', '노와이어브라'],
#  ['107', '써스데이아일랜드블라우스'],
#  ['108', '남자청바지'],
#  ['109', '핸드메이드코트'],
#  ['110', '몽클레어여성패딩'],
#  ['111', '남자맨투맨'],
#  ['112', '여성자켓'],
#  ['113', '후아유후드집업'],
#  ['114', '린원피스'],
#  ['115', '샤틴원피스'],
#  ['116', 'cp컴퍼니'],
#  ['117', '플리츠원피스'],
#  ['118', '청원피스'],
#  ['119', '폴로걸즈가디건'],
#  ['120', '오즈세컨'],
#  ['101', '남자바람막이'],
#  ['122', '여자폴로가디건'],
#  ['123', '파자마'],
#  ['124', '남성트레이닝세트'],
#  ['125', '코트'],
#  ['126', '플리츠스커트'],
#  ['127', '커플시밀러룩'],
#  ['128', '쉬즈미스'],
#  ['129', '라코스테'],
#  ['130', '케네스레이디'],
#  ['131', '남성드로즈'],
#  ['132', '나이키윈드러너'],
#  ['133', '남자반팔티'],
#  ['134', '남자드로즈'],
#  ['135', '보라끌레르'],
#  ['136', '니트'],
#  ['137', '빈폴레이디스'],
#  ['138', '쥬시쥬디원피스'],
#  ['139', '나이키바지'],
#  ['140', '폴로맨투맨'],
#  ['121', '베네통'],
#  ['122', '여자폴로가디건'],
#  ['123', '파자마'],
#  ['144', '롱패딩'],
#  ['145', '크롭맨투맨'],
#  ['146', '여자버버리트렌치코트'],
#  ['147', '올리비아로렌'],
#  ['148', '나이키조거팬츠'],
#  ['149', '셔츠'],
#  ['150', '몽클레어바람막이'],
#  ['151', '루시앙'],
#  ['152', '온앤온블라우스'],
#  ['153', '남자속옷'],
#  ['154', '티셔츠'],
#  ['155', '리바이스'],
#  ['156', '쉬폰원피스'],
#  ['157', '자켓'],
#  ['158', '아디다스져지'],
#  ['159', '심리스브라'],
#  ['160', '보브원피스'],
#  ['161', '원더브라'],
#  ['162', '크롭자켓'],
#  ['163', '숏패딩'],
#  ['164', '판초우의'],
#  ['165', '타미힐피거가디건'],
#  ['166', 'jj지고트원피스'],
#  ['167', '쥬크원피스'],
#  ['168', '여성티셔츠'],
#  ['169', '땀복'],
#  ['170', '쥬시꾸뛰르'],
#  ['171', '남성팬티'],
#  ['172', '톰보이'],
#  ['173', '써스데이아일랜드가디건'],
#  ['174', '엘레쎄'],
#  ['175', '언더아머'],
#  ['176', '브라이덜샤워원피스'],
#  ['177', '라이프워크'],
#  ['178', '트위드가디건'],
#  ['179', '제시뉴욕'],
#  ['180', '온앤온'],
#  ['181', '여성정장세트'],
#  ['182', '시슬리'],
#  ['183', '폴로후드집업'],
#  ['184', '남자긴팔티'],
#  ['185', '폴로'],
#  ['186', '심리스팬티'],
#  ['187', '나이키'],
#  ['188', '이자벨마랑맨투맨'],
#  ['189', '라코스테맨투맨'],
#  ['190', '막스마라'],
#  ['191', '스퀘어넥원피스'],
#  ['192', '톰브라운맨투맨'],
#  ['193', '여자게스청바지'],
#  ['194', '무스너클'],
#  ['195', '쉬즈미스블라우스'],
#  ['196', '코데즈컴바인이너웨어'],
#  ['197', '나이스클랍'],
#  ['198', '지컷블라우스'],
#  ['199', '여성맨투맨'],
#  ['200', 'bcbg원피스'],
#  ['201', '남자가죽자켓'],
#  ['202', '클라이드앤'],
#  ['203', '헤지스원피스'],
#  ['204', '럭키슈에뜨'],
#  ['205', '보브'],
#  ['206', '나이키반바지'],
#  ['207', '아디다스후드집업'],
#  ['208', '아디다스맨투맨'],
#  ['209', '지오다노'],
#  ['210', '올앤선드리'],
#  ['211', '베네통원피스'],
#  ['212', '여성바람막이'],
#  ['213', '여자청자켓'],
#  ['214', '로엠블라우스'],
#  ['215', '자라'],
#  ['216', '여성가죽자켓'],
#  ['217', '점프수트'],
#  ['218', '브라'],
#  ['219', '후아유'],
#  ['220', '베스트'],
#  ['221', '가을롱원피스'],
#  ['222', '랩원피스'],
#  ['223', '리스트블라우스'],
#  ['224', '속옷'],
#  ['225', '크롭가디건'],
#  ['226', '플라스틱아일랜드'],
#  ['227', '여성가을원피스'],
#  ['228', '티렌'],
#  ['229', '반에이크'],
#  ['230', '조끼'],
#  ['231', '이자벨마랑'],
#  ['232', '발렌시아'],
#  ['233', '남자바지'],
#  ['234', '슬립'],
#  ['235', '여성니트티'],
#  ['236', '씨씨콜렉트'],
#  ['237', '칼하트후드집업'],
#  ['238', '트위드투피스'],
#  ['239', '스톤아일랜드바람막이'],
#  ['240', '여성셔츠'],
#  ['241', '여성잠옷'],
#  ['242', '남자조거팬츠'],
#  ['243', '리스트원피스'],
#  ['244', '남자슬랙스'],
#  ['245', '잇미샤블라우스'],
#  ['246', '레이스원피스'],
#  ['247', '후드원피스'],
#  ['248', '자주잠옷'],
#  ['249', '라스벳'],
#  ['250', '아디다스'],
#  ['251', '캐시미어코트'],
#  ['252', '한복'],
#  ['253', '버버리프랭크비퀼팅자켓'],
#  ['254', '나이스클랍원피스'],
#  ['255', '리스트'],
#  ['256', '항공점퍼'],
#  ['257', '웨딩드레스'],
#  ['258', '스톤아일랜드후드집업'],
#  ['259', '스톤아일랜드패딩'],
#  ['260', '데님스커트'],
#  ['261', '올리브데올리브원피스'],
#  ['262', '폴로랄프로렌가디건'],
#  ['263', '엠씨'],
#  ['264', '바람막이자켓'],
#  ['265', '미쏘'],
#  ['266', '다이나핏'],
#  ['267', '나이키반팔'],
#  ['268', '반팔니트'],
#  ['269', '스투시'],
#  ['270', '오르시떼여성잠옷'],
#  ['271', 'bcbg'],
#  ['272', '크로커다일레이디'],
#  ['273', '남성정장'],
#  ['274', '헤지스레이디스'],
#  ['275', '빅사이즈원피스'],
#  ['276', '패딩'],
#  ['277', '아디다스반바지'],
#  ['278', '더봄'],
#  ['279', '여자슬랙스'],
#  ['280', '아르마니익스체인지'],
#  ['281', '청자켓'],
#  ['282', '파타고니아후리스'],
#  ['283', '몽클레어패딩'],
#  ['284', '헤지스남성티셔츠'],
#  ['285', '내셔널지오그래픽'],
#  ['286', '보니스팍스'],
#  ['287', '스톤아일랜드자켓'],
#  ['288', '남자트렌치코트'],
#  ['289', '숲원피스'],
#  ['290', '스투시후드집업'],
#  ['291', '쥬크블라우스'],
#  ['292', '레깅스'],
#  ['293', '슬랙스'],
#  ['294', '탑텐'],
#  ['295', '레코브'],
#  ['296', '톰브라운셔츠'],
#  ['297', '지오송지오'],
#  ['298', '라인원피스'],
#  ['299', '레인코트'],
#  ['300', '퍼프블라우스'],
#  ['301', '미니원피스'],
#  ['302', '라코스테셔츠'],
#  ['303', '챔피온후드집업'],
#  ['304', '폴로반팔티'],
#  ['305', '트렌치원피스'],
#  ['306', '우의'],
#  ['307', '메종키츠네반팔'],
#  ['308', '브라탑'],
#  ['309', '여자와이드팬츠'],
#  ['310', '감탄브라'],
#  ['311', '룰루레몬'],
#  ['312', '여성트렌치코트'],
#  ['313', '작업조끼'],
#  ['314', '지고트'],
#  ['315', 'cc콜렉트'],
#  ['316', '폴로반팔니트'],
#  ['317', '타미힐피거맨투맨'],
#  ['318', '남성트레이닝바지'],
#  ['319', '올리브데올리브'],
#  ['320', '원피스잠옷'],
#  ['321', '여성속옷'],
#  ['322', '아디다스바지'],
#  ['323', '무스너클패딩'],
#  ['324', '내셔널지오그래픽맨투맨'],
#  ['325', '여자사각팬티'],
#  ['326', '나이키프렌치테리후드'],
#  ['327', '여성긴팔티셔츠'],
#  ['328', '레이나'],
#  ['329', '하이웨스트청바지'],
#  ['330', '가을블라우스'],
#  ['331', '체크원피스'],
#  ['332', '파라점퍼스'],
#  ['333', '남성바람막이'],
#  ['334', '투피스'],
#  ['335', '새틴스커트'],
#  ['336', '지오다노셔츠'],
#  ['337', '야상점퍼'],
#  ['338', '여성면팬티'],
#  ['339', '아미니트'],
#  ['340', '아디다스아노락'],
#  ['341', '한복대여'],
#  ['342', '경량패딩'],
#  ['343', '위생팬티'],
#  ['344', '남성폴로셔츠'],
#  ['345', '남자반바지'],
#  ['346', '톰보이트렌치코트'],
#  ['347', '남성카고바지'],
#  ['348', '가죽자켓'],
#  ['349', '몽클레어'],
#  ['350', '머메이드스커트'],
#  ['351', '롱가디건'],
#  ['352', '나이키티셔츠'],
#  ['353', '캘빈클라인'],
#  ['354', '큐컴버스'],
#  ['355', '아미후드티'],
#  ['356', '아크메드라비'],
#  ['357', '내셔널지오그래픽패딩'],
#  ['358', '세인트제임스길도'],
#  ['359', '샤스커트'],
#  ['360', '스위치123'],
#  ['361', '리바이스청바지'],
#  ['362', '로엠자켓'],
#  ['363', '아디다스트랙탑'],
#  ['364', '에블린속옷'],
#  ['365', '엠에스지엠'],
#  ['366', '남성청바지'],
#  ['367', '여자폴로셔츠'],
#  ['368', '톰브라운니트'],
#  ['369', '홈웨어'],
#  ['370', '타미힐피거셔츠'],
#  ['371', '플레어스커트'],
#  ['372', '정장원피스'],
#  ['373', '나이키스포츠브라'],
#  ['374', '모조에스핀블라우스'],
#  ['375', '샤틴'],
#  ['376', '데일리'],
#  ['377', '폴로랄프로렌셔츠'],
#  ['378', 'cp컴퍼니맨투맨'],
#  ['379', '지오다노슬랙스'],
#  ['380', '제시뉴욕원피스'],
#  ['381', '나이키프렌치테리'],
#  ['382', '여성트레이닝바지'],
#  ['383', '레노마레이디'],
#  ['384', '여자크롭티'],
#  ['385', '폴로반집업'],
#  ['386', '바지'],
#  ['387', '버버리패딩'],
#  ['388', '나이키바람막이여성'],
#  ['389', '아미셔츠'],
#  ['390', '가을자켓'],
#  ['391', '남자레깅스'],
#  ['392', '리스트트렌치코트'],
#  ['393', '발렌시아원피스'],
#  ['394', '라코스테반팔티'],
#  ['395', '바스락원피스'],
#  ['396', '남자오버핏셔츠'],
#  ['397', '여성정장'],
#  ['398', '주크원피스'],
#  ['399', '씨씨콜렉트원피스'],
#  ['400', '남자후드티'],
#  ['401', '긴팔원피스'],
#  ['402', '타미힐피거여성'],
#  ['403', '브래지어'],
#  ['404', '리스트자켓'],
#  ['405', '아디다스후드티'],
#  ['406', '남자니트'],
#  ['407', '나이키후드'],
#  ['408', '남자정장'],
#  ['409', '아노락원피스'],
#  ['410', 'ggpx원피스'],
#  ['411', '생리팬티'],
#  ['412', '여자청바지'],
#  ['413', '마실러'],
#  ['414', '톰보이코트'],
#  ['415', '폴로옥스포드셔츠'],
#  ['416', '더아이잗원피스'],
#  ['417', '블루페페'],
#  ['418', '강블리블링면스판속바지'],
#  ['419', '나이키반팔티'],
#  ['420', '청치마'],
#  ['421', '야상'],
#  ['422', '트렁크팬티'],
#  ['423', '여자바버자켓'],
#  ['424', '모조에스핀코트'],
#  ['425', '빅카라블라우스'],
#  ['426', '쟈딕앤볼테르'],
#  ['427', '톰보이자켓'],
#  ['428', '남자티셔츠'],
#  ['429', '헬더'],
#  ['430', '오즈세컨원피스'],
#  ['431', '언더아머반바지'],
#  ['432', '볼레로가디건'],
#  ['433', '무스너클버니스웨터'],
#  ['434', '리버클래시'],
#  ['435', '퐁당'],
#  ['436', '산드로가디건'],
#  ['437', '겐조맨투맨'],
#  ['438', '아디다스원피스'],
#  ['439', '톰보이원피스'],
#  ['440', '나이키레깅스'],
#  ['441', '나이키에센셜프렌치테리후디'],
#  ['442', '시리즈'],
#  ['443', 'h라인스커트'],
#  ['444', '티렌원피스'],
#  ['445', '칼라거펠트'],
#  ['446', '보웬니트'],
#  ['447', '와이드팬츠'],
#  ['448', '아미'],
#  ['449', '여자바디프로필의상'],
#  ['450', '레니본원피스'],
#  ['451', '남자면바지'],
#  ['452', '폴로브이넥니트'],
#  ['453', '여름원피스'],
#  ['454', '내셔널지오그래픽바람막이'],
#  ['455', '온앤온코트'],
#  ['456', '커플속옷'],
#  ['457', '여성패딩'],
#  ['458', '남자우비'],
#  ['459', '짱구잠옷'],
#  ['460', '질스튜어트원피스'],
#  ['461', '코스'],
#  ['462', '여자와이드청바지'],
#  ['463', '아노락트레이닝세트'],
#  ['464', '베네통티셔츠'],
#  ['465', '나이키테크팩'],
#  ['466', '글리머'],
#  ['467', '여성반팔티셔츠'],
#  ['468', '에블린'],
#  ['469', '보웬원피스'],
#  ['470', '타미힐피거원피스'],
#  ['471', '커플룩'],
#  ['472', '트레이닝바지'],
#  ['473', '라코스테니트'],
#  ['474', '트위드조끼'],
#  ['475', '블랙원피스'],
#  ['476', '와이즈'],
#  ['477', '몽클레어남자패딩'],
#  ['478', '나이키에센셜프렌치테리'],
#  ['479', '르샵원피스'],
#  ['480', '나인'],
#  ['481', '지센'],
#  ['482', '시에로'],
#  ['483', '분더가이스트'],
#  ['484', '모조에스핀자켓'],
#  ['485', '여성청바지'],
#  ['486', '오버핏후드티'],
#  ['487', '여자땀복'],
#  ['488', '바버'],
#  ['489', '팬티'],
#  ['490', '프릴블라우스'],
#  ['491', '레더스커트'],
#  ['492', '여자맨투맨'],
#  ['493', '헤지스여성티셔츠'],
#  ['494', '봄이'],
#  ['495', '자바나스'],
#  ['496', '메종키츠네니트'],
#  ['497', '씨씨콜렉트블라우스'],
#  ['498', '남자청자켓'],
#  ['499', '비옷'],
#  ['500', '올리비아하슬러']]

# %% [markdown]
# - https://auto.naver.com/bike/mainList.nhn   [실습]

# %%
driver = webdriver.Chrome(path) 
driver.get('https://auto.naver.com/bike/mainList.nhn')

a_tag = driver.find_element_by_css_selector('#container > div.spot_main > div.spot_aside > div.tit > a')
a_tag.click()

# %%
time.sleep(3)

# %%
li_tags = driver.find_elements_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.emblem_area > ul > li')
li_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="c9e171dd-9db8-4bbd-bf45-45277c417841")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="0bdd05f1-1ffc-4866-8110-d90b10bc8d56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="b576d435-a59a-4ee4-9577-d1f8d6cd0349")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="81276819-39e7-49d9-a3c3-06cc30aae0bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="db9aeb85-54fa-4c9b-a3b6-94892b63bd28")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="8ab41696-26a7-4f1f-84f7-b08149f255d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="94a7d080-282d-4c71-9038-a1f9f41511fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="7f2a5c35-2773-423f-811d-dd334b491afc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="ce063777-469b-4593-bdd9-133e6333a484")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="85a50ae0-c180-47e3-a90d-f994c53f2679")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="d6245ec6-f5db-4091-9759-d19f6557c5bc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="56bd83d8-2209-4da7-81b5-c18f60d5e296")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="8d1ebe1d-ca52-47be-8bb6-56d1478ea766")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="5ebe7846-71ef-46a7-8f3c-2a58b28eb976")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="283b9551-2949-4d9f-861c-78ffd9ee97f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="a2a12e22-b98a-435f-813a-d1a35af4b09f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="1f9c7f33-097b-4349-a0a0-c724a2094da4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="99e64dd3-0d52-4ca5-8f2f-4760007b4656")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="fb3e1a69-ea48-44d7-895b-7ef10e42dba1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="5d63103c-2949-41eb-a3b1-b3ed2273a6fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="a221a345-a8e0-4248-a9bd-7d38b3f95a5f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="38c715bf-06e3-4279-b9cb-47f21ad0f51e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="a951fae9-08b7-4201-9c32-faf55a8c1c23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="e12200ae-a581-4edf-9082-e567eec7998c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="7e3660a4-bc5b-4070-9fb8-1ea34d9a71ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="62c1e3f7-4420-4b20-8b78-4bfec1f6f413")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="783f5f5c-7723-4ab0-ba58-d0054bfd0acc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="d8accce7-381c-4024-ad7d-eb810d60966a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="eec25196-370d-4928-a289-a5bedb097f39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="aebd5713-85cb-4cd7-8e92-951314deb282")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="2ba9e1e3-52cf-4793-96c7-7032194a1665")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="60e95dd9-4922-4050-85e0-435234f44c91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="e42d4c8c-d3bf-46a0-8b6d-947d7423e112")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="d68e188f-67a1-4d02-b1e2-459080c3195d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="e04232e2-ac98-4f66-a0ff-01799b2a6082")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="9c7f6a23-1d88-4dfd-bb54-2636b75c6ccb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="e5b64ee1-0b93-4d99-8311-567f651a6bc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="004e68ac-9a13-4873-b2b5-1d9a7a1137af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="c9a78c65-14ac-4275-9a64-a16251791161")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="b8316ee4-cd33-4ad9-9710-653edecd1947")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="2036fc4d-9c32-4d97-ab6d-9da10ca71a2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="4f7b845b-bcc6-410b-9564-b5c5d03730c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="7aeebf15-90f9-41c8-ad3f-7007700dcb5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="826536a0-e8da-4e35-a2b5-26f3c9dd8451")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="634472d8-cda8-49ce-aab2-09588221474d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="a66b5298-0608-4689-aaf7-8f325e0a6101")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="f842d3e2-163c-4136-b875-50e2c3c43020")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="512c53ca-f04e-4672-b379-6eb7c75c9a1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="afdf58b8-cb8c-4c02-812c-cd76dc943cf7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="c038348c-91da-4a48-8790-17785fc59b0c")>]

# %%
for li in li_tags : 
    brandName = li.find_element_by_tag_name('span').text
    # print(brandName)
    img_src = li.find_element_by_tag_name('img').get_attribute('src')
    a_href  = li.find_element_by_tag_name('a').get_attribute('href')
    # print(img_src , a_href)

# %%
cnt = driver.find_elements_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.emblem_area')
for idx in range(1, len(cnt)+1) :
    print(idx)
# Out:
# 1
# 2

# %%
print('button click - ')
print()
nextBtn = driver.find_element_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.rolling_btn > button.next')
nextBtn
# Out:
# button click -
# <selenium.webdriver.remote.webelement.WebElement (session="a8ac0017f8215a054e0e6c0182f66e1b", element="184592e1-7bc6-4eda-9d00-8aca2482bc7f")>

# %%
print('완성코드 - ')
print()

driver = webdriver.Chrome(path) 
driver.get('https://auto.naver.com/bike/mainList.nhn')

a_tag = driver.find_element_by_css_selector('#container > div.spot_main > div.spot_aside > div.tit > a')
a_tag.click()

time.sleep(2)

nextBtn = driver.find_element_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.rolling_btn > button.next')

for idx in range(1, len(cnt)+1) :
    print('page - ' , idx)
    li_tags = driver.find_elements_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.emblem_area > ul > li')
    
    for li in li_tags : 
        brandName = li.find_element_by_tag_name('span').text
        
        if brandName != '' :
            print(brandName)    
            img_src = li.find_element_by_tag_name('img').get_attribute('src')
            print(img_src)
            a_href  = li.find_element_by_tag_name('a').get_attribute('href')
            print(a_href)
            
    print("*" *  100)
    time.sleep(2)
    nextBtn.click()

driver.quit()
# Out:
# 완성코드 -
#
# page -  1
# BMW
# https://imgauto-phinf.pstatic.net/20200310_295/auto_1583815693764w1MIK_PNG/20200310134808_90XTo2CB.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=1
# DNA모터스
# https://imgauto-phinf.pstatic.net/20200306_144/auto_15834768484981kxOH_PNG/20200306154043_IDCmgkrX.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=9
# KR모터스
# https://imgauto-phinf.pstatic.net/20170707_35/auto_1499403672996veFiV_PNG/20170707140110_ZApVlmYd.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=8
# KTM
# https://imgauto-phinf.pstatic.net/20170707_86/auto_1499403489069IzvOn_PNG/20170707135806_pkMHEZto.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=2
# MV아구스타
# https://imgauto-phinf.pstatic.net/20200106_247/auto_1578277573120pRONl_PNG/20200106112605_VEPQ942y.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=3
# SYM
# https://imgauto-phinf.pstatic.net/20170707_69/auto_1499403691607hzmLc_PNG/20170707140129_Xm9IraXN.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=10
# 가와사키
# https://imgauto-phinf.pstatic.net/20170707_59/auto_149940389771698gvt_PNG/20170707140453_6HUCrEO2.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=41
# 고고로
# https://imgauto-phinf.pstatic.net/20200416_104/auto_1586997772907Atf4o_PNG/20200416094251_R0tdenWI.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=53
# 니우
# https://imgauto-phinf.pstatic.net/20200211_29/auto_1581399734416yzf4y_PNG/20200211144210_pcR4hM1R.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=57
# 다임러
# https://imgauto-phinf.pstatic.net/20191001_115/auto_1569895638495sGCl3_PNG/20191001110710_0Iz3JxnE.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=55
# 닷지
# https://imgauto-phinf.pstatic.net/20210105_214/auto_1609829278733SBqbs_PNG/20210105154752_NSfj620M.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=49
# 두카티
# https://imgauto-phinf.pstatic.net/20210804_36/auto_1628039462919v1Qjr_PNG/20210804101056_zh5bYy6k.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=4
# 람브레타
# https://imgauto-phinf.pstatic.net/20210705_203/auto_1625465297990YC43Y_PNG/20210705150741_lNjsPt3v.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=25
# 로얄엔필드
# https://imgauto-phinf.pstatic.net/20200306_19/auto_1583477817595DPct8_PNG/20200306155650_3gvEUisW.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=42
# 모토구찌
# https://imgauto-phinf.pstatic.net/20170707_99/auto_1499403620377SUY2j_PNG/20170707140017_av0Q5DJc.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=29
# 모헤닉
# https://imgauto-phinf.pstatic.net/20210128_107/auto_1611802036852yKlsH_PNG/20210128114656_FZwOEOEF.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=63
# 베넬리
# https://imgauto-phinf.pstatic.net/20170707_298/auto_149940364282830FB7_PNG/20170707140039_OqhQgzrP.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=43
# 베스파
# https://imgauto-phinf.pstatic.net/20200327_83/auto_1585299495007d9vwj_PNG/20200327175807_32P7N286.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=18
# 베타
# https://imgauto-phinf.pstatic.net/20170707_243/auto_14994036600550xR8J_PNG/20170707140054_w9OPzFyf.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=48
# 벡트릭스
# https://imgauto-phinf.pstatic.net/20200210_173/auto_1581309211901Ln2bN_PNG/20200210133325_SXnXm7QZ.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=21
# 브라모
# https://imgauto-phinf.pstatic.net/20200210_57/auto_1581309461684tMTzd_PNG/20200210133737_ctyiecRp.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=37
# 브릭스톤
# https://imgauto-phinf.pstatic.net/20210705_12/auto_1625466410870uWqgF_PNG/20210705152633_B303CT9J.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=67
# 블루샤크
# https://imgauto-phinf.pstatic.net/20200508_160/auto_1588926919938O09H0_PNG/20200508173447_Baivq88R.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=59
# 비모타
# https://imgauto-phinf.pstatic.net/20200210_3/auto_1581309342460Cq8L8_PNG/20200210133537_wb4NnXGT.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=33
# 빅토리
# https://imgauto-phinf.pstatic.net/20170707_250/auto_14994037310380lT41_PNG/20170707140207_nsPJJvuu.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=12
# 빅토리아
# https://imgauto-phinf.pstatic.net/20210820_61/auto_1629428219169uSqqC_PNG/20210820115425_HAy6vX01.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=46
# 스즈키
# https://imgauto-phinf.pstatic.net/20200207_262/auto_1581063025431IYOlm_PNG/20200207171020_tdJyUmbe.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=15
# 시엔케이
# https://imgauto-phinf.pstatic.net/20210708_14/auto_16257292425159OnVE_PNG/20210708162709_nDal3EoI.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=71
# 아치
# https://imgauto-phinf.pstatic.net/20210803_167/auto_1627967239521ns21K_PNG/20210803140713_3ptUKnv9.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=13
# 아프릴리아
# https://imgauto-phinf.pstatic.net/20170707_51/auto_149940352335462EyU_PNG/20170707135841_A8okFmzI.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=5
# 야마하
# https://imgauto-phinf.pstatic.net/20210803_248/auto_1627967814625aoAG1_PNG/20210803141649_pgyo9qjV.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=16
# 에임스
# https://imgauto-phinf.pstatic.net/20210727_264/auto_1627345746504DbYvS_PNG/20210727092824_hcQSjEqk.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=73
# 우랄
# https://imgauto-phinf.pstatic.net/20200511_32/auto_15891568939650ytfw_PNG/20200511092807_YSQPYQ6H.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=51
# 이쿠터
# https://imgauto-phinf.pstatic.net/20210708_72/auto_1625729189834EiIjR_PNG/20210708162613_Rmxn6AtJ.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=69
# 이탈젯
# https://imgauto-phinf.pstatic.net/20170707_35/auto_1499403573966MA2Ky_PNG/20170707135931_xisfE6sK.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=20
# ****************************************************************************************************
# page -  2
# 인디언
# https://imgauto-phinf.pstatic.net/20200306_94/auto_1583478005716frPcW_PNG/20200306160000_F7jTJnAI.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=19
# 제로
# https://imgauto-phinf.pstatic.net/20200211_86/auto_1581399544042tVyrG_PNG/20200211143900_Aak3gllx.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=45
# 질레라
# https://imgauto-phinf.pstatic.net/20170707_150/auto_1499403534722ObiKh_PNG/20170707135852_N2uEr3sk.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=6
# 캔암 BRP
# https://imgauto-phinf.pstatic.net/20170707_228/auto_1499403938849PIyMC_PNG/20170707140536_X569kcW8.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=35
# 킴코
# https://imgauto-phinf.pstatic.net/20201231_221/auto_16093853338058lJ22_PNG/20201231122846_qOxSdZtd.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=11
# 트라이엄프
# https://imgauto-phinf.pstatic.net/20200306_108/auto_1583477219918l17tk_PNG/20200306154654_VfKRcDoV.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=31
# 폴라리스
# https://imgauto-phinf.pstatic.net/20200306_92/auto_1583477538592tLpg2_PNG/20200306155212_sRrEH7Nu.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=27
# 푸조
# https://imgauto-phinf.pstatic.net/20210802_199/auto_16278886238164rPJj_PNG/20210802161657_Y6AiG76T.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=23
# 플레타
# https://imgauto-phinf.pstatic.net/20210412_49/auto_1618193696261Hqxna_PNG/20210412111434_d9AXZSJ5.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=65
# 피아지오
# https://imgauto-phinf.pstatic.net/20200327_205/auto_158529962401670gMc_PNG/20200327180019_F8e27mnu.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=7
# 하우주
# https://imgauto-phinf.pstatic.net/20200723_150/auto_1595476251516fKWJu_PNG/20200723125012_KwPALXVG.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=61
# 할리데이비슨
# https://imgauto-phinf.pstatic.net/20181114_217/auto_1542158042259qoTKx_PNG/20181114101352_mrZAwjhU.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=14
# 허스크바나
# https://imgauto-phinf.pstatic.net/20190822_21/auto_1566435071526vqkPl_PNG/20190822094926_kGG402zL.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=39
# 혼다
# https://imgauto-phinf.pstatic.net/20170707_49/auto_1499409167916Uizy9_PNG/20170707153243_h5zKjsaD.png?type=f30_30
# https://auto.naver.com/bike/mnfcoMain.nhn?mnfcoNo=17
# ****************************************************************************************************

# %% [markdown]
# #### XPATH
#
# - 절대경로를 이용한 노드 탐색
# - 노드선택 <div name='test' , id='content'>
# - driver.find_element_by_xpath('//div[@id='content']')
# - * 매칭되는 모든 요소 , @* 매칭되는 모든 속성의 노드

# %%
driver = webdriver.Chrome(path) 
driver.get('http://deal.11st.co.kr/html/nc/deal/main.html')

# %%
print('css selector - ')
print()

li_tags = driver.find_elements_by_css_selector('#emergencyPrd > div > ul > li')
for li in li_tags : 
    title = li.find_element_by_css_selector('div > a > div.prd_info > p > span.fs_16')
    price = li.find_element_by_css_selector('div > a > div.prd_info > div > span.price_detail > strong')
        
    print(title.text)
    print(price.get_attribute('innerHTML'))
    print("*" * 50)

print()
print('xpath - ')
print()


# //*[@id="2037093280"]/div/a/div[3]/p/span[2]
# //*[@id="1117907464"]/div/a/div[3]/p/span[2]
# //*[@id="3027359070"]/div/a/div[3]/p/span

# //*[@id="2037093280"]/div/a/div[3]/div/span[2]/strong
# //*[@id="1117907464"]/div/a/div[3]/div/span[2]/strong

li_tags = driver.find_elements_by_xpath('//*[@id="emergencyPrd"]/div/ul/li[position() <= 3]')

for li in li_tags : 
    title = li.find_element_by_xpath('div/a/div[3]/p/span[2]')
    price = li.find_element_by_xpath('div/a/div[3]/div/span[2]/strong')
        
    print(title.text)
    print(price.get_attribute('innerHTML'))
    print("*" * 50)
# Out:
# css selector -
#
# [밀크마일] 한가위 특별 S.A.L.E! 상하복/원피스/레깅스/가디건 外
# 6,900
# **************************************************
# [25%+T11%] 아모레퍼시픽 가을 보습대전! 에스트라/라네즈/아이오페/한율/마몽드 11번가 단독 특별구성
# 17,500
# **************************************************
# [리바트]9/16(목)! 코모 가드니아 쿼츠 주방 특가+후드OR핸드블랜더+냄비세트+3구법랑쿡탑+쿠폰가115만~
# 1,159,900
# **************************************************
# [Z플립 5G 자급제 쿠폰가 831,600원][사은품증정+서울당일수령]삼성 갤럭시 5G/LTE유심호환
# 924,000
# **************************************************
# [혜택가7,370원] 파크론 주방매트 발매트 PVC 규조토 브레드폼 매트크리너
# 7,920
# **************************************************
# [30%+2천원+T11%] 홀리카홀리카X11번가 추석 BIG세일 신상&베스트 (쉐이퍼/칫솔카라/라이너/섀도우/굳세라)
# 9,500
# **************************************************
# 깨끗한나라 순수 시그니처 3겹 천연펄프 화장지 27m 30롤 x 2팩+화장지 4롤
# 23,030
# **************************************************
# 중복쿠폰+SK pay 3만 최종가 819,000원 [LG 공식판매점] 퓨리케어 360도 공기청정기 플러스 AS281DWFC 2단
# 869,000
# **************************************************
# [MNC] 가을신상 BEST 필수 아이템 완벽 풀코디! 긴팔티/맨투맨/팬츠/아우터
# 9,900
# **************************************************
# 갤럭시 A32 64G
# 374,000
# **************************************************
# [한정수량 특가] 제주 삼다수 2L 6병
# 5,290
# **************************************************
# 꼬마시 벌교 양념/불/간장 햇꼬막장150g x 5통
# 19,950
# **************************************************
# 30%쿠폰!가을신상 업뎃! DOSSY도씨/피치기모/홈웨어/잠옷/카카오프렌즈잠옷/원피스/상하세트/커
# 10,900
# **************************************************
# 스파클 생수 2L 24개+ 500ml 20개 증정
# 12,900
# **************************************************
# [공식]9/16 추석한정 청호 직수정수기+렌탈료 1년치 지원/렌탈료 최대 8천원 할인 프로모션 / 얼음정수기, 비데, 공기청정기 청호나이스 렌탈
# 15,900
# **************************************************
# [최대40만]LG헬로 음식물처리기 25만증정/ 삼성가전 LG가전 종합렌탈 기획전 1회 무료 / 제휴카드 16,000원 할.인 / 음식물처리기 판매1위 /그린싱크 세탁기 냉장고 청소기 슈드레서 렌탈
# 16,900
# **************************************************
# [롯데렌터카]추석맞이 카니발/모델Y 외 신차 특별가 + 11번가 단독혜택! 롯데렌트카/장기렌트카/차량렌탈
# 194,180
# **************************************************
# 단하루 최종:115만! 삼성전자 갤럭시북 프로 NT950XDY-A51A /i5-1135G7/16GB/256GB/색상선택/노트북/온라인
# 1,329,000
# **************************************************
# [로즈몽]서현진이 선택한 로즈몽 신상품&베스트 주얼리 선물추천
# 17,500
# **************************************************
# [관부가세포함]샤넬/ 셀린느 / 프라다 / 버버리 외 명품 가방 & 지갑 모음전
# 455,400
# **************************************************
# 아이두젠 에이카트 다용도 접이식 핸드 카트
# 9,900
# **************************************************
# [농협안심한우]1+등급 명절 선물세트 등심/채끝/부채/불고기/국거리
# 97,670
# **************************************************
# [그린너트] 에브리데이넛츠 25g 30+30봉 하루 견과류 세트
# 22,900
# **************************************************
# [9/16 카드할인가 17,490원~] GNM 건강한 간 밀크씨슬 선물세트 / 루테인 지아잔틴 오메가3 / 유산균 외
# 19,430
# **************************************************
# [30%+복수]삭스팩토리 남자 여자 패션양말/정장/장목/덧신/가을
# 9,900
# **************************************************
# 콜핑 FW 신상입고 바람막이자켓/후리스/티셔츠/팬츠 모음전
# 8,930
# **************************************************
# [단하루] 추석이벤트! 신비아파트시즌4 & 쥬라기캅스시즌3 런칭 기념 이벤트!!!
# 14,700
# **************************************************
# [기프티콘] 파리바게뜨 카카오&딸기 레이어케이크
# 17,600
# **************************************************
# 오랄비 BEST [초미세모/토탈/잇몸케어] 칫솔 12입 모음
# 8,750
# **************************************************
# 켈로그 그래놀라 시리얼 1+1+증정)미니 시리얼 40g/망고바나나/블루베리/리얼/현미/크랜베리/통귀리/프로틴
# 8,900
# **************************************************
#
# xpath -
#
# [밀크마일] 한가위 특별 S.A.L.E! 상하복/원피스/레깅스/가디건 外
# 6,900
# **************************************************
# [25%+T11%] 아모레퍼시픽 가을 보습대전! 에스트라/라네즈/아이오페/한율/마몽드 11번가 단독 특별구성
# 17,500
# **************************************************
# [리바트]9/16(목)! 코모 가드니아 쿼츠 주방 특가+후드OR핸드블랜더+냄비세트+3구법랑쿡탑+쿠폰가115만~
# 1,159,900
# **************************************************

# %% [markdown]
# - https://www.ildong.com/kor/product/list.id?page=10&halt=&prdDisease=&prdCategory=1&searchVal=&searchOption=0

# %%
driver = webdriver.Chrome(path)

# %%
driver = webdriver.Chrome(path) 
for page in range(1, 3) :
    url = 'https://www.ildong.com/kor/product/list.id?page='+str(page)+'&halt=&prdDisease=&prdCategory=1&searchVal=&searchOption=0'
    driver.get(url)
    time.sleep(2)
    print('page  - ' , page)
    
    prList = driver.find_element_by_class_name('prList')
    a_tags = prList.find_elements_by_tag_name('a')    
    # print(a_tags)
        
    
    for idx in range(0 , 9) :
        a_tags[idx].click()
        tag = driver.find_element_by_class_name('detailCnt2')
        print(tag.text)
        print("*" * 100)
        time.sleep(2)
        driver.back()
        
        prList = driver.find_element_by_class_name('prList')
        a_tags = prList.find_elements_by_tag_name('a')    
    
    
driver.quit()
# Out:
# page  -  1
# 성분/함량
#
# L-아르기닌 73.1mg/mL
# 베타인 50mg/mL
# 베타인염산염 50mg/mL
# 시트르산수화물 29.4mg/mL
#
#
# 효능/효과
#
# 간질환의 보조 치료
#
#
# 용법/용량
#
# 성인 : 1일 10-30mL를 식간에 분할 복용한다.
# 이 약 10mL를 약 반 컵의 물에 희석하여 복용한다.
#
#
# 포장단위
#
# 30 vial
# ****************************************************************************************************
# 성분/함량
#
# 원료약품 및 분량 (100mL 중)
# ■ 유효성분 : 아세트아미노펜(KP) 1000.0mg, 클로르페니라민말레산염(KP) 8.3mg, 티페피딘시트르산염(KP) 66.6mg, dl-메틸에페드린염산염(KP) 83.3mg, 카페인수화물(KP) 83.3mg
# ■ 첨가제(보존제) : 파라옥시벤조산메틸 70.0mg, 파라옥시벤조산프로필 30.0mg
# ■ 기타 첨가제 : D-소르비톨액, 그레이프후레바, 글리세린, 백당, 베타덱스, 시트르산나트륨수화물, 시트르산수화물, 정제수
#
#
# 효능/효과
#
# 감기 제증상(콧물, 코막힘, 재채기, 인후통, 기침, 가래, 오한, 발열, 두통, 관절통, 근육통)의 완화
#
#
# 용법/용량
#
# 다음의 1회 용량을 1일 4회 식후 30분 및 취침 시에 복용한다.
# 어린이 1회 만 11세 이상 - 만 15세 미만 10㎖
# 만 7세 이상 - 만 11세 미만 7㎖
# 만3세 이상 - 만 7세 미만 5㎖
# 만2세 이상 - 만 3세 미만 3㎖
# 만 2세 미만 : 만 2세 미만에게 투여하지 않는다.
# 다만, 꼭 필요한 경우 의사의 진료를 받는다
#
#
# 포장단위
#
# 90ml
# ****************************************************************************************************
# 성분/함량
#
# 1g 중
# 유효성분 : 히드로코르티손아세테이트(KP) 5.00mg, 디펜히드라민염산염(KP) 5.00mg, 산화아연(KP) 20.00mg
# 첨가제(보존제) : 클로로크레졸 1.0mg
# 기타 첨가제 : 경질유동파라핀, 마크로골세토스테아릴에텔, 백색바세린, 세토스테아릴알콜, 정제수
#
#
# 효능/효과
#
# 습진, 땀띠, 피부가려움, 알레르기 피부질환, 화상, 동상
#
#
# 용법/용량
#
# 1일 2~3회 환부에 적당량을 바릅니다.
#
#
# 포장단위
#
# 15g
# ****************************************************************************************************
# 성분/함량
#
# 원료약품 및 분량 (1정 중)
# ■ 유효성분 : 옥수수불검화정량추출물(KHP)(총 β-sitosterol로서 7.0㎎) 35㎎
# ■ 첨가제(타르색소) : 황색4호, 황색5호, 청색2호
# ■ 첨가제(동물유래성분) : 유당수화물(소, 우유)
# ■ 기타 첨가제 : 무수인산수소칼슘, 미결정셀룰로오스, 스테아르산마그네슘, 오파글로스클리어97W19196, 오파드라이 200 오렌지 200F630014, 오파드라이OY-S-7223 흰색, 전분클리콜산나트륨, 코포비돈, 콜로이드성이산화규소, 탤크, 히드록시프로필셀룰로오스
#
#
# 효능/효과
#
# 지추 치료 후 치은염, 경 중등도 치주염의 보조치료
#
#
# 용법/용량
#
# 성인 : 초기량으로는 옥수수의 불검화정량추출물로서 1회 70mg 1일 3회 식전에 경구투여 한다.
# 유지량으로는 1회 35mg 1일 3회 식전에 투여한다.
# 연령, 증상에 따라 적절히 증감한다.
#
#
# 포장단위
#
# 120T, 240T, 360T
# ****************************************************************************************************
# 성분/함량
#
# 원료약품 및 분량 (1g 중)
# ■ 유효성분 : 세틸피리디늄염화물(USP) 0.5 mg, 토코페롤아세테이트(KP) 20 mg, 에녹솔론(EP) 3.0 mg
# ■ 기타 첨가제 : D-소르비톨액, L-멘톨, 녹차향 G-5101, 라우릴황산나트륨, 사카린나트륨수화물, 인산삼칼슘, 자스민민트향 HF-63077, 자스민향 FAC-17861, 자일리톨, 자일리톨향 HF-60582, 정제수, 카르복시메틸셀룰로오스나트륨, 페퍼민트향 HF-6701, 폴리에틸렌글리콜1500, 피로인산나트륨, 함수규산
#
#
# 효능/효과
#
# 치은염(잇몸염) · 치조(이틀)농루에 의한 여러 증상 (잇몸의 발적(충열되어 붉어짐)·부종·고름, 구취)의 완화
#
#
# 용법/용량
#
# 1회 이 약 적량(약 0.3g(약 0.5cm))을 칫솔에 묻혀 1일 2회(아침, 저녁) 잇몸을 마사지한다.
# 사용 후 물로 가볍게 헹굴 수 있다
#
#
# 포장단위
#
# 200g
# ****************************************************************************************************
# 성분/함량
#
# (1캡슐 중)
# •유효성분 : 바실루스서브틸리스균, 엔테로코쿠스페슘균 배양물 250mg (생균수로서 엔테로코쿠스페슘 9.0X108 개, 바실루스서브틸리스 1.0X108개)
# •첨가제(타르색소) : 황색5호, 황색203호, 청색1호
# •첨가제(동물유래성분) : 유당수화물(소, 우유)
# •기타 첨가제 : 글리세린, 디아세틸레이티드모노글리세라이드, 스테아르산마그네슘, 캡슐, 탤크, 히프로멜로오스, 히프로멜로오스프탈레이트
#
#
# 효능/효과
#
# 정장, 변비, 묽은 변, 복부팽만감, 장내이상발효
#
#
# 용법/용량
#
# 성인 및 12세 이상의 소아 : 바실루스서브틸리스균 · 엔테로코쿠스페슘균 배양물로서 1회 125 ∼ 250 mg(생균수로서 5.0 × 108 ∼ 1.0 × 109개)을 1일 1 ∼ 3회 경구복용합니다.
#
#
# 포장단위
#
# 30, 300C
# ****************************************************************************************************
# 성분/함량
#
# 원료약품 및 분량 (1정 중)
# ■유효성분 :
# 피리독신염산염(KP) (비타민B6) 10.0mg
# 티아민질산염(KP) (비타민B1) 1.5mg
# 시아노코발라민1000배산(KP) (비타민B12) (시아노코발라민으로서 6㎍) 6.0mg
# 리보플라빈(KP) (비타민B2) 1.7mg
# 아스코르브산(직타용)(별규) (비타민C) (아스코르브산으로서 60.0mg) 61.86mg
# 폴산(USP) (엽산, 비타민B9) 1000.0㎍
# 비오틴(USP)  (비타민H) 300.0㎍
# 니코틴산아미드(KP) (비타민B3) 20.0mg
# 판토텐산칼슘(KP)   (비타민B5) 10.0mg
#   ■첨가제(타르색소) :
# 황색203호, 황색5호
# ■기타 첨가제 :
# 무수인산수소칼슘, 미결정셀룰로오스, 스테아르산마그네슘, 오파글로스클리어(97W19196), 오파드라이노란색(80W42062),
# 오파드라이 흰색(OY-C-7000A), 저치환도히드록시프로필셀룰로오스, 콜로이드성이산화규소, 탤크, 히드록시프로필셀룰로오스
#
#
# 효능/효과
#
# 투석환자, 만성신부전에 의한 질소혈증 환자의 비타민 B, C 보급
#
#
# 용법/용량
#
# 성인 1회 1정, 1일 1회 복용
#
#
# 포장단위
#
# 60T
# ****************************************************************************************************
# 성분/함량
#
# -유효성분: 록소프로펜나트륨수화물 94.77mg
# -첨가제(보존제): 파라옥시벤조산메틸 9.8mg, 파라옥시벤조산프로필 4.9mg
# -기타 첨가제: D-소르비톨액(70%),ㅣ-멘톨, 농글리세린, 디이소프로판올아민, 디프로필렌글리콜, 디히드록시알루미늄아미노아세테이트수화물, 밀착포, 부직포, 산화티탄, 에데트산나트륨수화물, 우레아, 정제수, 젤라틴, 카르복시메틸셀룰로오스나트륨, 카올린, 타르타르산, 페릭옥사이드, 폴리비닐알코올, 폴리아크릴산나트륨, 폴리아크릴산액, 폴리에틸렌테레프탈레이트 세파레이터, 플록사머
#
#
# 효능/효과
#
# 다음 질환 및 증상의 진통, 소염: 퇴행성관절염(골관절염), 근육통, 외상후의 종창, 통증
#
#
# 용법/용량
#
# 1일 1회 1매 환부에 부착한다.
#
#
# 포장단위
#
# 5매
# ****************************************************************************************************
# 제품특징
#
# 활성비타민을 함유한 근육경련 및 혈액순환 개선제
#
#
# 성분/함량
#
# ■유효성분 :
# 토코페롤아세테이트 (비타민E로서 500 IU) (KP) 500mg
# 산화마그네슘 (마그네슘으로서 150.8mg) (KP) 250mg
# 푸르설티아민 (KP) (활성비타민B1) 50mg
# 피리독신염산염 (KP) (비타민B6) 50mg
# 시아노코발라민 (KP) (비타민B12) 500㎍
# 감마오리자놀 (KP) 5mg
#   ■기타 첨가제 :
# 농글리세린, 레시틴, 백납, 산화철, 소르비톨액(비결정성), 숙신산젤라틴, 에틸바닐린, 중쇄트리글리세리드, 카르나우바납, 콩기름
#
#
# 효능/효과
#
# ○ 다음 경우의 비타민 E, B1, B6의 보급
# - 육체피로
# - 임신·수유기
# - 병중·병후(병을 앓는 동안이나 회복 후)의 체력저하시
# - 노년기
# - 이 약에 함유된 비타민 등의 효능·효과는 다음과 같습니다.
# • 말초혈행장애 및 갱년기시 다음 증상의 완화 :
# 어깨·목결림, 수족저림·수족냉증(손발이 차가움)
# • 다음 증상의 완화 : 신경통, 근육통, 관절통(요통, 어깨결림 등),
# 구각염(입꼬리염), 구순염(입술염), 구내염(입안염), 설염(혀염), 습진, 피부염
# • 각기
# • 눈의 피로
# ○ 마그네슘결핍으로 인한 근육경련
#
#
# 용법/용량
#
# 만 12세 이상 및 성인 : 1회 1캡슐, 1일 2회
#
#
# 포장단위
#
# 60, 120캡슐
# ****************************************************************************************************
# page  -  2
# 성분/함량
#
# 원료약품 및 분량 (1정 중)
# ■ 유효성분 :
# 레티놀아세테이트과립(EP)(동물유래성분 : 돼지, 피부, 젤라틴)(비타민A로서2500IU) 5.0mg
# β-카로틴20%과립(별규)(베타카로틴으로서 0.6mg) 3.0mg
# 토코페롤아세테이트2배산(KP)(동물유래성분 : 돼지, 피부, 젤라틴)(비타민E로서 30IU) 60.0mg
# 콜레칼시페롤과립(별규)(동물유래성분 : 소, 가죽, 젤라틴)(비타민D로서 400IU) 4.0mg
# 피토나디온5%(별규)(비타민K로서 60㎍) 1.2mg
# 제피아스코브르산(별규)(비타민C)(아스코브르산으로서 60mg) 62.5mg
# 니코틴산아미드3배산(KP)(니코틴산아미드로서 20mg) 60.0mg
# 피리독신염산염3배산(KP)(비타민B6)(피리독신염산염으로서 2mg) 6.0mg
# 티아민질산염3배산(KP)(비타민B1)(티아민질산염으로서 1.5mg) 4.5mg
# 리보플라빈(KP)(비타민B2) 1.7mg
# 폴산(USP)(비타민B9) 0.5mg
# 시아노코발라민1000배산(KP)(비타민B12)(시아노코발라민으로서 10㎍) 10.0mg
# 비오틴(USP) (비타민H) 0.030mg
# 판토텐산칼슘(KP)  (비타민B5) 10.87mg
# 무수인산수소칼슘(KP)(총 칼슘으로서 63.83mg, 인으로서 48.62mg) 213.6mg
# 푸마르산철(KP)(철로서 4.0mg) 12.2mg
# 산화마그네슘(KP)(마그네슘으로서 100mg) 165.8mg
# 산화제이구리(KP)(구리로서 2mg) 2.5mg
# 산화아연(KP)(아연으로서 15mg) 18.7mg
# 셀레늄함유건조효모(KP)(셀레늄으로서 25㎍) 46.3mg
# 염화크롬(USP)(크롬으로서 25㎍) 0.128mg
# 몰리브덴함유건조효모(별규)(몰리브덴으로서 25㎍) 12.5mg
# 황산망간수화물(USP)(망간으로서 2mg) 6.15mg
# 염화칼륨(KP)(칼륨으로서 8.0mg) 15.179mg
# 이노시톨(KP) 25.0mg
# γ-오리자놀(KP) 5.0mg
#   ■ 첨가제(타르색소) : 황색5호
# ■ 첨가제(동물유래성분) : 유당수화물(소, 우유)
# ■ 기타 첨가제 : 미결정셀룰로오스, 스테아르산, 아크릴이즈 MP 흰색(93O18508), 오파글로스클리어(97W19196), 오파드라이AMB주황색(80W43065), 저치환도히드록시프로필셀룰로오스, 코포비돈, 탤크, 폴리에틸렌글리콜6000, 히드록시프로필셀룰로오스, 히프로멜로오스
#
#
# 효능/효과
#
# ○ 다음경우의 비타민 A, D, E, B1, B2, B6, C의 보급
# - 육체피로
# - 임신·수유기
# - 병중·병후(병을 앓는 동안이나 회복 후)의 체력저하시
# - 발육기
# - 노년기
#   - 이 약에 함유된 비타민 등의 효능효과는 다음과 같다.
# ·비타민A : 눈의 건조감의 완화, 야맹증(밤에 잘 못보는 증상)
# ·비타민D : 뼈, 이의 발육불량, 구루병의 예방
#   ○ 아연의 보급
#
#
# 용법/용량
#
# 만 12세 이상 및 성인: 1일 1회 1정
#
#
# 포장단위
#
# 30정(보건소용), 100정
# ****************************************************************************************************
# 성분/함량
#
# (100g 중)
# 유효성분: 테르비나핀염산염 1.0g
# 첨가제(보존제): 파라옥시벤조산메틸 0.1g
# 기타 첨가제: 농글리세린, 에탄올, 염산, 정제수, 폴리에틸렌글리콜 400, 프로필렌글리콜
#
#
# 효능/효과
#
# 1. Trichophyton(T. rubrum, T. mentagrophytes, T. verrucosum, T. violaceum), Microsporum canis 및 Epidermophyton floccosum과 같은 피부사상균에 의한 피부진균감염증 : 족부백선, 고부백선(완선), 체부백선
#   2. Pityrosporum orbiculare (Malassezia furfur)에 의한 어루러기
#
#
# 용법/용량
#
# 적응증에 따라 1일 1회 또는 2회 적용합니다. 적용전에 환부를 깨끗이 씻고, 완전히 건조시킨 후 환부와 그 주위가 충분히 적셔지도록 충분한 양을 바릅니다.
#   치료기간 :
#   1. 족부백선, 고부백선(완선), 체부백선 : 1일 1회, 1주
# 2. 어루러기 : 1일 2회, 1주 증상의 경감은 보통 2-3일 이내에 나타납니다.
# 감염 재발을 방지하려면 이 약으로 적정기간 동안 정기적으로 치료합니다.
# 치료기간 이후에도 임상적인 증상이 개선되지 않으면 진단을 다시 해야 합니다.
#
#
# 포장단위
#
# 30mL
# ****************************************************************************************************
# 제품특징
#
# 무조라실크림은 합성 allyamine 유도체로 진균에서 sterol 생합성에 가장 중요한 효소인 squalene epoxidase를 억제해서 진균의 세포막에서 ergosterol을 결핍시킴으로써 항진균작용을 나타낸다.
#
#
# 성분/함량
#
# 유효성분: 테르비나핀염산염(JP) 10mg
# 첨가제(보존제): 파라옥시벤조산메틸 1.6mg, 파라옥시벤조산프로필 0.4mg
# 기타 첨가제: 농글리세린, 디메치콘, 디스테아릴디모늄염화물, 백색바셀린, 세탄올, 염화나트륨, 이소프로필팔미테이트, 정제수, 트리에탄올아민
#
#
# 효능/효과
#
# 1. Trichophyton(T. rubrum, T. mentagrophytes, T. verrucosum, T. violaceum), Microsporum canis 및 Epidermophyton floccosum과 같은 피부사상균에 의한 피부진균감염증 : 족부백선(무좀), 고부백선{완선(사타구니백선)}, 체부백선
# 2. Pityrosporum orbiculare (Malassezia furfur)에 의한 어루러기
# 3. 피부칸디다증
#
#
# 용법/용량
#
# 1일 1-2회 환부(질환부위)에 바릅니다. 질환에 따른 치료기간은 다음과 같습니다.
# 1. 족부백선 : 1일 1회, 1주
#    지간형(발가락 사이) 족부백선 : 1일 2회, 1주
#    족저형(발바닥) 족부백선 : 1일 2회, 2주
# 2. 체부백선, 고부백선 : 1-2주
# 3. 피부칸디다증 : 1-2주
# 4. 어루러기 : 2주, 치료기간 이후에도 임상적인 증상이 개선되지 않으면 진단을 다시 해야 합니다.
#
#
# 포장단위
#
# 15g
# ****************************************************************************************************
# 성분/함량
#
# 유효성분: 테르비나핀염산염 10mg, 글리시리진산이칼륨 5mg, 리도카인 20mg, L-멘톨 10mg
# 첨가제(보존제): 파라옥시벤조산메틸 1mg, 파라옥시벤조신프로필 1mg
# 기타 첨가제: 세탄올, 수산화나트륨, 스테아릴알코올, 정제수, 카보어940, 폴리소르베이트60, 프로필렌글리콜
#
#
# 효능/효과
#
# 피부사상균에 의한 피부진균감염증 : 무좀, 완선(사타구니백선), 백선
#
#
# 용법/용량
#
# 1일 1회, 적당량을 환부에 도포한다.
#
#
# 포장단위
#
# 20g
# ****************************************************************************************************
# 성분/함량
#
# 유효성분 : 데소게스트렐(USP)0.15mg,에티닐에스트라디올(USP)0.02mg
# 첨가제 : 토코페롤,히프로멜로오스,전호화전분,경질무수규산,유당수화물,포비돈,스테아르산,산화티탄,폴리에틸렌글리콜6000,탤크
#
#
# 효능/효과
#
# 피임
#
#
# 용법/용량
#
# 1. 복용 방법
#  정제는 매일 대략 같은 시간에, 물과 함께, 포장에 표시된 순서대로 복용해야 한다. 1일 1정씩 21일간 복용하고, 7일간 휴약한 후 새로운 포장을 시작한다. 7일의 휴약 기간 동안 보통 소퇴성 출혈이 나타나는데, 대개 마지막 정제 복용 후 2~3일에 시작되며, 새로운 포장을 시작하기 전에 끝나지 않을 수도 있다.
#
# 2. 복용 시작 방법
# 1) 지난달 호르몬 피임제를 사용 안 한 경우
# : 정제 복용은 여성의 자연 주기의 첫 날(즉, 월경의 첫 날) 시작해야 한다. 2~5일째에 시작할 수 있지만, 첫 번째 주기 동안 정제 복용 처음 7일간은 차단피임법(예: 콘돔)을 병행해야 한다.
#
# 2)복합호르몬피임제{복합경구피임제(COC), 질링 또는 경피패취제}에서 바꾸는 경우
# : 가능하면 기존 복용하던 복합경구피임제의 마지막 유효성분 정제(주성분이 포함된 마지막 정제)를 복용한 다음 날 이 약의 복용을 시작하되,
# 늦어도 기존 복용하던 복합경구피임제의 통상적인 휴약기간이나 마지막 위약 정제 복용 다음 날 이 약의 복용을 시작해야 한다. 질링이나 경피패취제를 사용한 경우에는, 가능하면 제거한 날 이 약의 복용을 시작하되, 늦어도 이 제제들(질링이나 경피패취제)의 다음 사용 예정일에는 이 약의 복용을 시작해야 한다. 만약 이전의 피임법을 지속적으로 정확하게 사용해왔고 임신상태가 아님이 분명하다면, 기존의 복합호르몬피임제 복용 주기 중 어느 날이나 이 약으로 바꿀 수 있다. 이전 피임법의 휴약 기간은 권장된 기간을 절대로 넘겨선 안 된다.
#
# 3) 프로게스틴 단일제제(정제, 주사제, 임플란트) 또는 프로게스틴 유리 자궁내피임장치 (IUS)에서 바꾸는 경우
# : 프로게스틴정제 복용 중 어느 날이나 (임플란트 또는 프로게스틴 유리 자궁내피임장치의 경우 제거한 날, 주사제의 경우 다음 주사 예정일에) 이 약으로 바꿀 수 있다. 그러나 이 모든 경우에 처음 7일간은 차단피임법(예: 콘돔)을 병행해야 한다.
#
# 4) 임신 첫 3개월 내에 유산 후
# : 즉시 복용을 시작할 수 있다. 그런 경우, 부가적인 피임법을 병행할 필요는 없다.
#
# 5) 분만 후 또는 임신 4~6개월 사이에 유산 후
#  -수유부는 사용상의 주의사항 7. 임부 및 수유부에 대한 투여항을 참조한다.
#  -분만 후 또는 임신 4~6개월 사이에 유산 후 21일~28일 사이에 복용을 시작할 수 있다. 더 늦게 복용을 시작할 경우, 복용 후 첫 7일 동안 차단피임법을 병행해야 한다. 그러나, 성관계가 이미 이루어진 경우에는 임신이 되지 않았음을 확인하고 복합경구피임제의 복용을 시작하거나 첫 월경 기간까지 기다려야 한다.
#
# 3. 주기를 변경하거나 연장할 경우
#  주기를 연장시키기 위해서는 휴약 기간 없이 이 약의 새 포장을 순서대로 복용한다. 두 번째 포장을 다 복용할 때까지 원하는 기간만큼 연장할 수 있다. 연장 기간 동안 파탄 출혈 또는 점상출혈을 경험할 수 있다. 그런 다음 7일간의 휴약 기간 후 이 약의 복용을 정상적으로 다시 시작한다.
#  현재의 일정이 아닌 다른 날로 주기를 변경하기 위해서는 원하는 날짜만큼 다가올 휴약 기간을 줄일 수 있다. 휴약 기간이 짧아질수록, 소퇴성 출혈이 나타나지 않고 (주기를 연장할 때처럼) 두 번째 포장을 복용하는 동안 파탄 출혈 및 점상 출혈을 경험할 위험성이 높아진다.
# *자세한 사항은 제품 설명서 전문을 참조해주십시오.
#
#
# 포장단위
#
# 21T
# ****************************************************************************************************
# 성분/함량
#
# (1g 중)
# 유효성분: 아시클로버 50mg
# 첨가제(보존제): 파라옥시벤조산메틸 1mg, 파라옥시벤조산프로필 0.5mg
# 기타 첨가제: 세탄올, 소르비탄스테아레이트, 스테아르산, 시트르산수화물, 유동파라핀, 정제수, 폴리소르베이트60, 프로필렌글리콜
#
#
# 효능/효과
#
# 단순포진 바이러스 감염증 (초기 및 재발성 생식시포진과 구순포진 포함)
#
#
# 용법/용량
#
# 1) 이 약은 약 4시간 간격으로 1일 5회 환부에 바른다.
# 2) 치료는 5일간 계속하여야 하며, 5일간 사용 후에도 치료되지 않을 경우에는 5일간 더 사용할 수 있다.
#
#
# 포장단위
#
# 5g
# ****************************************************************************************************
# 성분/함량
#
# 원료약품 및 분량 (100mL 중)
# ■ 유효성분 : 아이비엽30%에탄올엑스(5~7.5 → 1)(별규) 700.0mg
# ■ 첨가제(보존제) : 소르빈산 칼륨 134.0mg
# ■ 기타 첨가제 : D-소르비톨액, 시트르산, 잔탄검, 정제수, 체리후레바
#
#
# 효능/효과
#
# 만성 염증성 기관지 질환의 증상 개선, 기침을 동반한 호흡기의 급성 염증 완화
#
#
# 용법/용량
#
# 성인 및 15세 이상 : 아이비엽30%에탄올건조엑스(5~7.5→1)로서 1회 35~52.5 mg(5~7.5ml)을 1일 2~3회 복용한다.
# 다만, 1일 최대 105 mg(15ml)을 넘지 않도록 한다.
# 6~14세 : 이 약으로서 1회 35 mg(5ml)을 1일 2회 복용한다
# 2~5세 : 이 약으로서 1회 17.5 mg(2.5ml)을 1일 2회 복용한다
#
#
# 포장단위
#
# 500mL
# ****************************************************************************************************
# 성분/함량
#
# • 유효성분 : 락토바실루스 스포로게네스균(생균수로서 8.0x107개)(별규) 40mg, 바실루스 서브틸리스균(생균수로서 12.0x105개)(별규) 12.0mg, 티아민질산염3배산(티아민질산염으로서 1.6mg)(KP) 4.8mg, 우르소데옥시콜산(KP) 10.0mg
# • 기타 첨가제 : 루디프레스, 스테아르산마그네슘, 오파드라이85F18422 흰색, 코포비돈
#
#
# 효능/효과
#
# 정장, 변비, 묽은 변, 복부(배부분)팽만감, 장내이상발효, 소화불량, 식욕감퇴(식욕부진), 과식, 체함, 소화촉진, 소화불량으로 인한 위부팽만감.
#
#
# 용법/용량
#
# 15세 이상 성인: 1회 2정, 1일 3회, 8~14세 : 1회 1정, 1일 3회
#
#
# 포장단위
#
# 360T, 720T
# ****************************************************************************************************
# 성분/함량
#
# 원료약품 및 분량 (100mL 중)
# ■ 유효성분 : 세티리진염산염(BP) 100mg
# ■ 첨가제(보존제) : 파라옥시벤조산메틸(KP) 70.0mg, 파라옥시벤조산프로필(KP) 30.0mg
# ■ 기타 첨가제 : D-소르비톨액, 농글리세린, 딸기향47, 시트르산나트륨수화물, 시트르산수화물, 정제수, 프로필렌글리콜
#
#
# 효능/효과
#
# 계절성 및 다년성 알레르기성 비염, 알레르기성 결막염, 피부소양증, 만성 특발성 두드러기
#
#
# 용법/용량
#
# 1. 성인 및 12세 이상의 소아 : 세티리진염산염으로서 1일 1회 10mg 경구 투여한다.
# 2. 2-12세 미만의 소아
# - 체중이 30kg이상인 경우 : 이 약으로서 1일 10mg 투여한다.
# - 체중이 30kg미만인 경우 : 이 약으로서 1일 5mg 투여한다.
# 3. 이상반응에 민감한 환자의 경우에는 아침, 저녁으로 분할 투여한다.
# 4. 연령, 증상에 따라 적절히 증감한다.
# 5. 중등도 ～ 중증의 신장애 환자 : 투여 간격은 환자의 신기능에 따라 조절되어야 한다.
# 다음 표를 참조하여 용량을 조절한다.
# 이 용량 표를 사용하기 위해서는 mL/min 단위의 크레아티닌 청소율 (CLcr)이 필요하다.
# CLcr (mL/min)은 다음 공식을 이용하여 혈청 크레아티닌 (mg/dL) 측정치로부터 계산된다 :
# CLcr = {[140 - 연령(세)] × 체중(kg)} / {72 × 혈청 크레아티닌(mg/dL)}(여성인 경우 × 0.85)
# 신기능이 손상된 성인 환자에 대한 용량 조절 [구분(크레아티닌청소율(ml/min)): 용량 및 빈도] 정 상(80 이상): 1일 1회 10mg(10mL) 경 증(50~79): 1일 1회 10mg(10mL) 중등도(30~49): 1일 1회 5mg(5mL) 중증(30 미만): 매2일마다 1회 5mg(5mL) 말기단계신질환 투석환자(10미만) 금기 신장애(신장장애)를 가진 소아 환자는 환자의 신 청소율과 체중을 고려하여 개별적으로 용량을 조절해야 한다.
#
#
# 포장단위
#
# 60ml
# ****************************************************************************************************
